# %%
#淘宝比价爬虫
#技术路线： requests-re
#程序结构设计
#1.提交商品搜索请求，循环获取页面
#2.提取每个页面的商品名称和价格
#3.将信息输出到屏幕商

# %%
import requests 
import re

def getHTMLText(url):
    try:
        r=requests.get(url,timeout=30)
        r.raise_for_status()
        r.encoding=r.apparent_encoding
#         print (r.text)
        return r.text
        
    except:
        return ""
def parsePage(ilt,html):
    try:
        plt=re.findall(r'\"view_price\"\:\"[\d\.]*\"',html)
        tlt=re.findall(r'\"raw_title\"\:\".*?\"',html)
        for i in range(len(plt)):
            price=eval(plt[i].split(':')[1])
            title=eval(tlt[i].split(':')[1])
            ilt.append([price,title])
    except:
        print("")
def printGoodsList(ilt):
    tplt="{:4}\t{:8}\t{:16}"
    print(tplt.format("序号","价格","名称"))
    count=0
    for g in ilt:
        count=count+1
        print(tplt.format(count,g[0],g[1]))
def main():
    goods='书包'
    depth=2
    start_url='https://s.taobao.com/search?q='+goods
    infoList=[]
    for i in range(depth):
        try:
            url=start_url+'&s='+str(44*i)
            html=getHTMLText(url)
            parsePage(infoList,html)
        except:
            continue
    printGoodsList(infoList)
main()
# Out:
# 序号  	价格      	名称
#    1	208.00  	杯具熊樱桃小丸子三一年级女男童小学生双肩
#    2	199.00  	Nike耐克官方旗舰书包男包女包2020夏季新款休闲包双肩包BA6032-
#    3	109.90  	森马大容量双肩包男款个性简约休闲校园背包时尚潮流中学生书包
#    4	22.00   	书包拉杆架通用小学生书包拉杆爬楼防水可拆卸书包拖拉杆车配件女
#    5	59.00   	迪士尼书包小学生男童女童儿童三到六年级一二护脊减负轻便超轻
#    6	39.90   	书包女中学生初中生韩版原宿ulzzang时尚潮流大学生ins双肩背包男
#    7	22.00   	男士双肩包大容量旅行电脑背包女高中初中学生时尚潮流书包大学生
#    8	59.00   	背包男士双肩包大容量电脑旅行时尚潮流大学生高中生初中学生书包
#    9	25.99   	小学生书包1-3-4-6年级男童女儿童双肩减负超轻背包6-12周岁男孩
#   10	96.00   	Nike耐克双肩包男学生书包女2020新款背包运动电脑旅行包大容量潮
#   11	59.80   	儿童书包小学生男女一二三到六年级韩版减负护脊贵族书包轻便防水
#   12	59.00   	双肩包男士大容量商务出差电脑背包女旅游旅行包高中初中学生书包
#   13	58.00   	小学生通用书包拉杆架男女孩三轮爬楼梯可折叠背包拖拉杆车架配件
#   14	37.90   	儿童书包小学生护脊三到六男童轻便幼儿园一年级女童二定制印logo
#   15	24.80   	儿童书包男女童韩版可爱大中小班3-5岁6幼儿园卡通男孩双肩背包包
#   16	129.00  	KK剑桥树书包小学生男孩一二三到六年级儿童6-12岁男童双肩包减负
#   17	49.00   	书包女韩版高中大容量百搭双肩包男大学生时尚潮流ins风情侣背包
#   18	39.00   	小学生书包儿童一二三到六年级男孩双肩包男童背包超轻便护脊减负
#   19	38.90   	新款书包小学生女孩一二三到六年级儿童可爱公主背包减负防水轻便
#   20	59.00   	可爱书包女ins韩版高中学生软妹日系初中生小学生大容量双肩背包
# ...

# %%
#上面是旧的课堂代码，由于反爬技术升级，已经用不了，必须更改过去获取网页内容的部分
#参考https://blog.csdn.net/Omann/article/details/104759719?utm_medium=distribute.pc_relevant.none-task-blog-BlogCommendFromMachineLearnPai2-2.add_param_isCf&depth_1-utm_source=distribute.pc_relevant.none-task-blog-BlogCommendFromMachineLearnPai2-2.add_param_isCf

# %%
def getHTMLText(url):
    try:
        header = {
    'authority': 'www.taobao.com',
    'cache-control': 'max-age=0',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.102 Safari/537.36 Edg/85.0.564.51',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'sec-fetch-site': 'cross-site',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-user': '?1',
    'sec-fetch-dest': 'document',
    'referer': 'https://cn.bing.com/',
    'accept-language': 'zh-CN,zh;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    'cookie': 't=d0457a066a8dd259d44046ba184294ef; UM_distinctid=1749686f90e54-0c4703292aabad-333769-1fa400-1749686f90fc40; enc=EfI6MQF6BrDiCBYHqcezSnrUMBlkq8%2Fbjd6w82ZPEcIDiX6VYWZkrSBprrkIrsI1AuQlBOxP%2BGKuexrBUCpblg%3D%3D; thw=cn; hng=CN%7Czh-CN%7CCNY%7C156; xlly_s=1; _m_h5_tk=11a5c400dcb3ac731fbdd0fc20f5bb80_1600693077691; _m_h5_tk_enc=2ca439563426a14c52cea22fb73a5638; cookie2=1fba353608cb8498cc78a65ed049ffba; _tb_token_=385b7b58e7ea3; _samesite_flag_=true; mt=ci=0_0; tracknick=; cna=4wiwFzlSeA8CAW8AUu+PV55Z; v=0; tfstk=cmX5BOs0940SwxNEUgZ28dKVACJCZWn6A7TlV_spWETYgwS5ixHw53BPt2dTxn1..; l=eBPbIHtgOzhcCkZsBOfwourza77OSIRAguPzaNbMiOCPOrCp5nyPWZr9DpY9C3GVh6lkR3P4acHBBeYBq3tSnxvtIosM_Ckmn; isg=BJSURbdEty8iUyPqMyv0U-OIZdIG7bjXxRVL4S51HZ-iGTVjVv0zZjyRHRGB4fAv',
    'if-none-match': 'W/"1c679-WzVw/v+F7Xx7Y0iBPUQIohSwU04"',
}
        r=requests.get(url,headers=header)
        r.raise_for_status()
        r.encoding=r.apparent_encoding
#         print (r.text)
        return r.text
        
    except:
        return ""
